# %% [markdown]
# <a href="https://colab.research.google.com/github/Julianajjss/100_days_of_code/blob/main/acidentes_de_trab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/drive/MyDrive/acidentes2022_todas_causas_tipos.csv", delimiter=';', encoding='ISO-8859-1')

# %%
df
# Out:
#             id      pesid data_inversa    dia_semana   horario  uf     br  \
# 0       405147   911178.0   2022-01-01        sábado  00:10:00  CE  222.0
# 1       405147   911179.0   2022-01-01        sábado  00:10:00  CE  222.0
# 2       405149   912796.0   2022-01-01        sábado  01:30:00  PE  104.0
# 3       405149   912793.0   2022-01-01        sábado  01:30:00  PE  104.0
# 4       405149   913204.0   2022-01-01        sábado  01:30:00  PE  104.0
# ...        ...        ...          ...           ...       ...  ..    ...
# 330380  475374  1030683.0   2022-08-31  quarta-feira  18:00:00  PE  104.0
# 330381  475374  1030682.0   2022-08-31  quarta-feira  18:00:00  PE  104.0
# 330382  475374  1030684.0   2022-08-31  quarta-feira  18:00:00  PE  104.0
# 330383  475374  1030683.0   2022-08-31  quarta-feira  18:00:00  PE  104.0
# 330384  475374  1030682.0   2022-08-31  quarta-feira  18:00:00  PE  104.0
#
#           km  municipio causa_principal  ...           sexo  ilesos  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 330385 entries, 0 to 330384
# Data columns (total 37 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   id                      330385 non-null  int64
#  1   pesid                   299292 non-null  float64
#  2   data_inversa            330385 non-null  object
#  3   dia_semana              330385 non-null  object
#  4   horario                 330385 non-null  object
#  5   uf                      330385 non-null  object
#  6   br                      329045 non-null  float64
#  7   km                      329045 non-null  object
#  8   municipio               330385 non-null  object
#  9   causa_principal         330385 non-null  object
#  10  causa_acidente          330385 non-null  object
#  11  ordem_tipo_acidente     330385 non-null  int64
#  12  tipo_acidente           330385 non-null  object
#  13  classificacao_acidente  330385 non-null  object
# ...

# %%
df.head()
# Out:
#        id     pesid data_inversa dia_semana   horario  uf     br   km  \
# 0  405147  911178.0   2022-01-01     sábado  00:10:00  CE  222.0  2,8
# 1  405147  911179.0   2022-01-01     sábado  00:10:00  CE  222.0  2,8
# 2  405149  912796.0   2022-01-01     sábado  01:30:00  PE  104.0   63
# 3  405149  912793.0   2022-01-01     sábado  01:30:00  PE  104.0   63
# 4  405149  913204.0   2022-01-01     sábado  01:30:00  PE  104.0   63
#
#    municipio causa_principal  ...           sexo  ilesos feridos_leves  \
# 0  FORTALEZA             Sim  ...      Masculino       1             0
# 1  FORTALEZA             Sim  ...      Masculino       0             0
# 2    CARUARU             Não  ...       Feminino       0             1
# 3    CARUARU             Não  ...      Masculino       0             0
# 4    CARUARU             Não  ...  Não Informado       0             0
#
#   feridos_graves mortos     latitude  longitude regional delegacia  \
# ...

# %%
df.shape
# Out:
# (330385, 37)

# %%
df

# %%
df.count()
# Out:
# id                        330385
# pesid                     299292
# data_inversa              330385
# dia_semana                330385
# horario                   330385
# uf                        330385
# br                        329045
# km                        329045
# municipio                 330385
# causa_principal           330385
# causa_acidente            330385
# ordem_tipo_acidente       330385
# tipo_acidente             330385
# classificacao_acidente    330385
# fase_dia                  330385
# sentido_via               330385
# condicao_metereologica    330385
# tipo_pista                330385
# tracado_via               330385
# uso_solo                  330385
# id_veiculo                330385
# tipo_veiculo              330385
# marca                     315602
# ano_fabricacao_veiculo    311857
# tipo_envolvido            330385
# estado_fisico             330385
# idade                     260487
# sexo                      330385
# ...

# %%
df.causa_acidente.value_counts().head(10)
# Out:
# Reação tardia ou ineficiente do condutor                     42448
# Velocidade Incompatível                                      34292
# Ausência de reação do condutor                               32443
# Condutor deixou de manter distância do veículo da frente     23054
# Acessar a via sem observar a presença dos outros veículos    20767
# Ingestão de álcool pelo condutor                             18350
# Manobra de mudança de faixa                                  17415
# Transitar na contramão                                       11988
# Condutor Dormindo                                            11411
# Ultrapassagem Indevida                                       10074
# Name: causa_acidente, dtype: int64
